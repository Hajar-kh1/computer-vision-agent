# %%
import torch

print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# GPU: Tesla T4

# %%
# !git clone https://github.com/Hajar-kh1/computer-vision-agent.git
# %cd computer-vision-agent
# Out:
# Cloning into 'computer-vision-agent'...
# remote: Enumerating objects: 129, done.
# remote: Counting objects: 100% (129/129), done.
# remote: Compressing objects: 100% (107/107), done.
# remote: Total 129 (delta 21), reused 123 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (129/129), 5.59 MiB | 38.70 MiB/s, done.
# Resolving deltas: 100% (21/21), done.
# /content/computer-vision-agent

# %%
# !ls
# Out:
# agent	      data	  frontend   pyproject.toml  tests
# backend       deployment  models     README.md	     training
# compose.yaml  docs	  openwebui  reports	     uv.lock

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-b4116996-d1ca-4eec-b30f-7a66ae8bfb1c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b4116996-d1ca-4eec-b30f-7a66ae8bfb1c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls -lh
# Out:
# total 45M
# drwxr-xr-x 2 root root 4.0K Aug 13 14:39  agent
# drwxr-xr-x 3 root root 4.0K Aug 13 14:39  backend
# -rw-r--r-- 1 root root 1.6K Aug 13 14:39  compose.yaml
# drwxr-xr-x 4 root root 4.0K Aug 13 14:39  data
# drwxr-xr-x 2 root root 4.0K Aug 13 14:39  deployment
# drwxr-xr-x 2 root root 4.0K Aug 13 14:39  docs
# drwxr-xr-x 3 root root 4.0K Aug 13 14:39  frontend
# drwxr-xr-x 2 root root 4.0K Aug 13 14:39  models
# drwxr-xr-x 2 root root 4.0K Aug 13 14:39  openwebui
# -rw-r--r-- 1 root root  45M Aug 13 14:43 'Package Detection.v6i.coco.zip'
# -rw-r--r-- 1 root root 1.1K Aug 13 14:39  pyproject.toml
# -rw-r--r-- 1 root root 4.0K Aug 13 14:39  README.md
# drwxr-xr-x 2 root root 4.0K Aug 13 14:39  reports
# drwxr-xr-x 2 root root 4.0K Aug 13 14:39  tests
# drwxr-xr-x 2 root root 4.0K Aug 13 14:39  training
# -rw-r--r-- 1 root root 114K Aug 13 14:39  uv.lock

# %%
# !mkdir -p data/raw/package_detection
# !unzip -q "Package Detection.v6i.coco.zip" -d data/raw/package_detection
# !ls data/raw/package_detection
# Out:
# README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
# !pip install -q uv
# !uv sync
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 95.6 MB/s eta 0:00:00
# Using CPython 3.12.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Resolved 49 packages in 1ms
# Prepared 46 packages in 51.13s
# Installed 46 packages in 460ms
#  + contourpy==1.3.3
#  + cuda-bindings==13.3.1
#  + cuda-pathfinder==1.6.0
#  + cuda-toolkit==13.0.3.0
#  + cycler==0.12.1
#  + filelock==3.32.2
#  + fonttools==4.63.0
#  + fsspec==2026.7.0
#  + jinja2==3.1.6
#  + joblib==1.5.3
#  + kiwisolver==1.5.0
#  + markupsafe==3.0.3
#  + matplotlib==3.11.1
#  + mpmath==1.3.0
#  + narwhals==2.24.0
#  + networkx==3.6.1
#  + numpy==2.5.2
#  + nvidia-cublas==13.1.1.3
#  + nvidia-cuda-cupti==13.0.85
#  + nvidia-cuda-nvrtc==13.0.88
#  + nvidia-cuda-runtime==13.0.96
#  + nvidia-cudnn-cu13==9.20.0.48
#  + nvidia-cufft==12.0.0.61
#  + nvidia-cufile==1.15.1.6
#  + nvidia-curand==10.4.0.35
#  + nvidia-cusolver==12.0.4.66
#  + nvidia-cusparse==12.6.3.3
# ...

# %%
# !uv run python -c "import torch; print('PyTorch:', torch.__version__); print('CUDA available:', torch.cuda.is_available()); print('GPU:', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'None')"
# Out:
# PyTorch: 2.13.0+cu130
# CUDA available: True
# GPU: Tesla T4

# %%
# !uv run python -m training.train \
  --data data/raw/package_detection \
  --epochs 5 \
  --batch-size 32 \
  --lr 0.001
# Out:
# Device: cuda
# Classes: ['Box', 'Box_broken', 'Open_package', 'Package']
# Training images: 835
# Validation images: 239
# Downloading: "https://download.pytorch.org/models/mobilenet_v3_small-047dcff4.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v3_small-047dcff4.pth
# 100.0%
# Epoch 1/5 | train_loss=0.7578 | val_loss=0.4888 | train_acc=0.7257 | val_acc=0.8577 | time=10.1s
# Saved new best model.
# Epoch 2/5 | train_loss=0.3543 | val_loss=0.3755 | train_acc=0.8790 | val_acc=0.8577 | time=7.5s
# Epoch 3/5 | train_loss=0.2417 | val_loss=0.2970 | train_acc=0.9186 | val_acc=0.9038 | time=8.5s
# Saved new best model.
# Epoch 4/5 | train_loss=0.2169 | val_loss=0.4196 | train_acc=0.9222 | val_acc=0.8870 | time=8.0s
# Epoch 5/5 | train_loss=0.3147 | val_loss=0.2548 | train_acc=0.8731 | val_acc=0.9121 | time=8.5s
# Saved new best model.
# Best validation accuracy: 0.9121
# Training time: 42.7 seconds
# Saved models/model.pt
# Saved models/labels.json
# ...

# %%
# !MPLBACKEND=Agg uv run python -m training.evaluate \
  --model models/model.pt \
  --data data/raw/package_detection
# Out:
# Device: cuda
# Test images: 119
# Test loss: 0.2189
# Test accuracy: 0.9244
# Weighted precision: 0.9310
# Weighted recall: 0.9244
# Weighted F1-score: 0.9250
# Saved reports/model_metrics.json
# Saved reports/confusion_matrix.png

# %%
from google.colab import files

files.download("models/model.pt")
files.download("models/labels.json")
files.download("reports/training_history.json")
files.download("reports/model_metrics.json")
files.download("reports/confusion_matrix.png")
